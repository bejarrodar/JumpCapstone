# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - hive</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="/?o=515233164903664#setting/sparkui/1006-183718-fc7jywu/driver-8522946136997164616">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.2.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[8]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Databricks Shell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
# !pip install sqlalchemy
# !pip install mysql-connector-python
# Out:
# ...
# WARNING: You are using pip version 21.0.1; however, version 22.2.2 is available.
# You should consider upgrading via the '/databricks/python3/bin/python -m pip install --upgrade pip' command.
# ...
#      |████▌
#
# *** WARNING: max output size exceeded, skipping output. ***
#
#      |████████████████████████████████| 25.4 MB 8.9 MB/s
# ...
# WARNING: You are using pip version 21.0.1; however, version 22.2.2 is available.
# You should consider upgrading via the '/databricks/python3/bin/python -m pip install --upgrade pip' command.

# %%
import pyspark.pandas as ps
import pandas as pd
import sqlalchemy

# %%
host = "database-1.cuwpussgwc5p.us-east-1.rds.amazonaws.com"
port = 3306
user = "root"
passw = "rootroot"
database = "Sales"

url = f"mysql+mysqlconnector://{user}:{passw}@{host}:{port}/{database}"
engine = sqlalchemy.create_engine(url)

# %%
pandasDF = pd.read_sql('SELECT * FROM April', con=engine)

# %%
sparkDF=spark.createDataFrame(pandasDF)
sparkDF.show()
# Out:
# +-----+--------+--------------------+----------------+----------+-------------------+--------------------+-----+----+------+-------------+
# |index|Order ID|             Product|Quantity Ordered|Price Each|         Order Date|    Purchase Address|month|time|  Cost|         city|
# +-----+--------+--------------------+----------------+----------+-------------------+--------------------+-----+----+------+-------------+
# |    0|  176558|USB-C Charging Cable|               2|     11.95|2019-04-19 08:46:00|917 1st St, Dalla...|    4|   8|  23.9|       Dallas|
# |    2|  176559|Bose SoundSport H...|               1|     99.99|2019-04-07 22:30:00|682 Chestnut St, ...|    4|  22| 99.99|       Boston|
# |    3|  176560|        Google Phone|               1|     600.0|2019-04-12 14:38:00|669 Spruce St, Lo...|    4|  14| 600.0|  Los Angeles|
# |    4|  176560|    Wired Headphones|               1|     11.99|2019-04-12 14:38:00|669 Spruce St, Lo...|    4|  14| 11.99|  Los Angeles|
# ...

# %%
df = ps.DataFrame(pandasDF)
df.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>index</th>
#       <th>Order ID</th>
#       <th>Product</th>
#       <th>Quantity Ordered</th>
#       <th>Price Each</th>
#       <th>Order Date</th>
#       <th>Purchase Address</th>
#       <th>month</th>
#       <th>time</th>
#       <th>Cost</th>
#       <th>city</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>176558</td>
#       <td>USB-C Charging Cable</td>
#       <td>2</td>
#       <td>11.95</td>
#       <td>2019-04-19 08:46:00</td>
#       <td>917 1st St, Dallas, TX 75001</td>
#       <td>4</td>
#       <td>8</td>
#       <td>23.90</td>
# ...
